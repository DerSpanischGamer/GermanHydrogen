# %%
import openpyxl
from disaggregator import data, plot, spatial

# %%
data.generate_specific_consumption_per_branch_and_district()
# Out:
# 2023-10-09 09:41:03 disaggregator.config: INFO     Querying from:
# http://opendata.ffe.de:4000/v_demandregio_spatial_lk401?id_spatial=eq.15&&year=eq.2015&&value=gt.0.0
# (         1001        1002        1003        1004        1051        1053   \
#  1    21.149487   21.149487   21.149487   21.149487   21.149487   21.149487
#  2     5.968424    5.968424    5.968424    5.968424    5.968424    5.968424
#  3    46.935305   46.935305   46.935305   46.935305   46.935305   46.935305
#  5   152.114501  220.454961  131.053860  142.678859  986.039172  153.530395
#  6    67.312679   97.554237   57.993067   63.137283  436.335378   67.939231
#  ..         ...         ...         ...         ...         ...         ...
#  95    6.693903    6.693903    6.693903    6.693903    6.693903    6.693903
#  96    6.693903    6.693903    6.693903    6.693903    6.693903    6.693903
#  97    6.693903    6.693903    6.693903    6.693903    6.693903    6.693903
# ...

# %%
data.living_space()
# Out:
# building_type           1FH           2FH     MFH_03_06     MFH_07_12  \
# nuts3
# DE111          3.403625e+06  2.081553e+06  7.937328e+06  6.709143e+06
# DE112          6.197582e+06  3.432353e+06  3.655280e+06  2.423038e+06
# DE113          8.000477e+06  4.431818e+06  6.000478e+06  3.206198e+06
# DE114          4.434813e+06  2.800774e+06  2.425602e+06  1.101553e+06
# DE115          8.145413e+06  4.317894e+06  5.876111e+06  3.531068e+06
# ...                     ...           ...           ...           ...
# DEG0K          1.826712e+06  8.697761e+05  7.115606e+05  4.746710e+05
# DEG0L          2.337477e+06  1.134761e+06  9.376636e+05  5.628105e+05
# DEG0M          1.788918e+06  7.080304e+05  1.123207e+06  8.880396e+05
# DEG0N          4.158143e+05  2.072282e+05  4.648653e+05  6.023400e+05
# DEG0P          2.647236e+06  1.499126e+06  9.071688e+05  5.935672e+05
#
# building_type     MFH_13_99
# nuts3
# DE111          3.507993e+06
# DE112          1.543025e+06
# ...

# %%
data.households_per_size()
# Out:
# hh_size       1      2      3      4     5     6
# nuts3
# DE111    128790  86757  35460  25968  8891  4381
# DE112     52484  51906  24381  21584  6891  2905
# DE113     78944  74585  33377  28722  8657  3612
# DE114     34386  35443  16924  14549  4639  1991
# DE115     77832  77216  32540  28915  8639  3626
# ...         ...    ...    ...    ...   ...   ...
# DEG0K     12943  13886   7386   4061  1106   509
# DEG0L     17763  18476   8902   4373  1085   429
# DEG0M     17958  18987   7259   3151   741   342
# DEG0N      9270   7839   2809   1332   347   156
# DEG0P     16137  19221  11473   6789  2051   977
#
# [401 rows x 6 columns]

# %%
fig, ax = plot.choropleth_map(data.households_per_size(), relative = False)
